# %%
import os
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(os.path.join('..', 'data', 'test.csv'), encoding='cp949', low_memory=False)

# %%
data.head()
# Out:
#     회계연도        판매일자  판매처코드                           판매처상호      판매처사업자번호  \
# 0  2020년  2020-07-01  40966  희창물산(주)(GUAM)                   6038111703.0
# 1  2020년  2020-07-01  40966  희창물산(주)(GUAM)                   6038111703.0
# 2  2020년  2020-07-01  40966  희창물산(주)(GUAM)                   6038111703.0
# 3  2020년  2020-07-01  40966  희창물산(주)(GUAM)                   6038111703.0
# 4  2020년  2020-07-01  40972        제이앤에이치인터내셔날               1283661207.0
#
#                재고계정구분            매출구분       품번코드  \
# 0  상품                  로컬수출송장          6113558.0
# 1  제품                  로컬수출송장          5141861.0
# 2  제품                  로컬수출송장          5141824.0
# 3  제품                  로컬수출송장          5141880.0
# 4  제품                  로컬수출송장          5129384.0
#
#                                     품명                                규격  ...  \
# 0  드림카카오72% 86g                          86g x 6통 x 4BOL                  ...
# ...

# %%
len(data)
# Out:
# 500000

# %%
data = pd.read_csv(os.path.join('..', 'data', '202007_utf.csv'), encoding='cp949')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# C:\Users\DT-SNO~1\AppData\Local\Temp/ipykernel_13884/2313381365.py in <module>
# ----> 1 data = pd.read_csv(os.path.join('..', 'data', '202007_utf.csv'), encoding='cp949')
#
# C:\Program Files\Python38\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
